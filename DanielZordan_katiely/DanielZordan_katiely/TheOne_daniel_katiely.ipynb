# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib notebook

# %%
#lendo o arquivo de simulacao
data =  pd.read_csv('r.one',sep=' ',header = None)

#colocando os indices
data.columns = ['tempo','id','X','Y']

lista_pontos = ( data['X'].values , data['Y'].values)

# %%
def limpaPontos(lista):
    for x in range(0,len(lista[0])):
        if( lista_pontos[0][x] < 0.1 ):
            lista_pontos[0][x] = 0
        if( lista_pontos[0][x] > 8250):
            lista_pontos[0][x] = 8250 
        if( lista_pontos[1][x] > 8500):
            lista_pontos[1][x] = 8500 
        if( lista_pontos[1][x] < 0.01 ):
            lista_pontos[1][x] = 0   
limpaPontos(lista_pontos)

# %%
def colocaMsmPonto(lista_pontos):
    for x in range(1, len(lista_pontos[0])):
        aux = (lista_pontos[0][x-1],lista_pontos[1][x-1])
        pt = (lista_pontos[0][x],lista_pontos[1][x])
        distancia = dist_euclidiana(aux,pt)
        if (distancia < 500):
            (lista_pontos[0][x],lista_pontos[1][x]) = aux

# %%
#mapa de calor 1
plt.ylim(-2000,8500)
plt.xlim(-2000,8500)
#mude o n_b se quiser maior definiçao
n_b = 200
plt.hist2d(lista_pontos[0], lista_pontos[1], bins=(n_b,n_b), cmap=plt.cm.jet)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
sns.jointplot('X', 'Y',data,color="red")
# Out:
# <img src="data:image/png;base64,..." width="599.9999869953505">

# %%
sns.set_style("white")
sns.kdeplot(data['X'],data['Y'], cmap="inferno_r", shade=True, shade_lowest=True, )
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
plt.ylim(-2000,8500)
plt.xlim(-2000,8500)
plt.plot(data['X'],data['Y'], color='r',marker='o', markersize=8)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
